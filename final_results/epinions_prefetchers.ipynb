# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
combined_data = pd.read_csv("epinions_prefetchers.csv")
print(combined_data)
# Out:
#        Base      DCTP  Indirect Memory  Signature    Tagged
# 0  0.823534  0.807999         0.732892   0.644820  0.607519
# 1  0.775584  0.753652         0.706054   0.602909  0.564125
# 2  0.909676  0.892750         0.896745   0.874238  0.869523

# %%
# set width of bar
barWidth = 0.1
 
# set height of bar
bars0 = list(combined_data['Base'])
bars1 = list(combined_data['DCTP'])
bars2 = list(combined_data['Indirect Memory'])
bars3 = list(combined_data['Signature'])
bars4 = list(combined_data['Tagged'])
 
# Set position of bar on X axis
r0 = np.arange(len(bars0))
r1 = [x + barWidth for x in r0]
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
 
# Make the plot
plt.bar(r0, bars0, color='black', width=barWidth, edgecolor='white', label='Base')
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='DCTP')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Indirect Memory')
plt.bar(r3, bars3, color='#0900ff', width=barWidth, edgecolor='white', label='Signature')
plt.bar(r4, bars4, color='#fff100', width=barWidth, edgecolor='white', label='Tagged')
 
# Add xticks on the middle of the group bars
plt.title("Epinions Dataset\n75888 nodes\n508837 edges")
plt.ylabel("LLC Miss Rate", fontweight='bold')
plt.xticks([r + barWidth*2 for r in range(len(bars1))], ['BFS', 'CC', 'PR'])
 
# Create legend & Show graphic
plt.legend(loc=(1.04,0))
plt.show()
